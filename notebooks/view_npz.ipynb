# %% [markdown]
# To visualize npz file

# %% [markdown]
# Data Loader

# %%
import json
import numpy as np
from pathlib import Path

# %%
repo_root = Path.cwd().parent

processed_root = repo_root / "data" / "ecg" / "processed" / "v1"

label_data = np.load(processed_root / "labels" / "label_shard_000.npz")
td_data = np.load(processed_root / "time_domain_data" / "td_shard_000.npz")
fd_data = np.load(processed_root / "frequency_domain_data" / "fd_shard_000.npz")

frequency_bins = np.load(processed_root / "frequency_bins.npz")["data"]

with open(processed_root / "label_map.json", "r") as f:
    label_map = json.load(f)

# %% [markdown]
# Print Keys

# %%
print("label keys:", label_data.files)
print("td keys:", td_data.files)
print("fd keys:", fd_data.files)
# Out:
# label keys: ['data']
# td keys: ['data']
# fd keys: ['data']

# %% [markdown]
# Inspect shapes and dtypes

# %%
for name, data in [("label", label_data), ("td", td_data), ("fd", fd_data)]:
    print(f"\n{name.upper()}")
    for key in data.files:
        arr = data[key]
        print(f"{key}: shape={arr.shape}, dtype={arr.dtype}")
# Out:
# LABEL
# data: shape=(110247,), dtype=int64
#
# TD
# data: shape=(110247, 2, 361), dtype=float32
#
# FD
# data: shape=(110247, 2, 181, 2), dtype=float32

# %% [markdown]
# To verify the stored content

# %%
label_arr = label_data["data"]
td_arr = td_data["data"]
fd_arr = fd_data["data"]

print("label_map:", label_map)
print("frequency_bins shape:", frequency_bins.shape)

print("\nFirst 10 labels:")
print(label_arr[:10])

print("\nOne TD sample shape:", td_arr[0].shape)
print("One FD sample shape:", fd_arr[0].shape)

print("\nTD sample 0, channel 0, first 10 values:")
print(td_arr[0, 0, :10])

print("\nFD sample 0, channel 0, first 5 frequency bins [magnitude, phase]:")
print(fd_arr[0, 0, :5, :])
# Out:
# label_map: {'N': 0, 'L': 1, 'R': 2, 'A': 3, 'a': 4, 'J': 5, 'S': 6, 'V': 7, 'F': 8, '[': 9, '!': 10, ']': 11, 'e': 12, 'j': 13, 'E': 14, '/': 15, 'f': 16, 'x': 17, 'Q': 18, '|': 19}
# frequency_bins shape: (145,)
#
# First 10 labels:
# [0 0 0 0 0 0 3 0 0 0]
#
# One TD sample shape: (2, 289)
# One FD sample shape: (2, 145, 2)
#
# TD sample 0, channel 0, first 10 values:
# [-0.31  -0.325 -0.31  -0.3   -0.29  -0.31  -0.325 -0.33  -0.315 -0.3  ]
#
# FD sample 0, channel 0, first 5 frequency bins [magnitude, phase]:
# [[ 1.1790569e-13  3.1415927e+00]
#  [ 1.1966861e+01 -1.4172208e+00]
#  [ 8.7643833e+00  1.6681379e+00]
#  [ 5.2365966e+00 -1.2226633e+00]
#  [ 1.1076684e+01 -3.0966680e+00]]

# %% [markdown]
# Frequency Bin Inspection

# %%
print("Frequency bins shape:", frequency_bins.shape)
print("Frequency resolution (Hz):", frequency_bins[1] - frequency_bins[0])

print("\nFirst 10 frequency bins (Hz):")
print(frequency_bins[:10])

print("\nLast 10 frequency bins (Hz):")
print(frequency_bins[-10:])

print("\nMin / Max frequency (Hz):")
print(frequency_bins[0], frequency_bins[-1])
# Out:
# Frequency bins shape: (181,)
# Frequency resolution (Hz): 0.997229916897507
#
# First 10 frequency bins (Hz):
# [0.         0.99722992 1.99445983 2.99168975 3.98891967 4.98614958
#  5.9833795  6.98060942 7.97783934 8.97506925]
#
# Last 10 frequency bins (Hz):
# [170.52631579 171.52354571 172.52077562 173.51800554 174.51523546
#  175.51246537 176.50969529 177.50692521 178.50415512 179.50138504]
#
# Min / Max frequency (Hz):
# 0.0 179.50138504155126

# %% [markdown]
# Label Map Inspection

# %%
unique_labels, counts = np.unique(label_arr, return_counts=True)

inv_label_map = {v: k for k, v in label_map.items()}

print("Label distribution:")
for label_id, count in zip(unique_labels, counts):
    print(f"{label_id:2d}  {inv_label_map[label_id]:>2s}  {count}")
# Out:
# Label distribution:
#  0   N  75019
#  1   L  8072
#  2   R  7255
#  3   A  2546
#  4   a  150
#  5   J  83
#  6   S  2
#  7   V  7129
#  8   F  802
#  9   [  6
# 10   !  472
# 11   ]  6
# 12   e  16
# 13   j  229
# 14   E  106
# 15   /  7024
# 16   f  982
# 17   x  193
# 18   Q  33
# 19   |  132
